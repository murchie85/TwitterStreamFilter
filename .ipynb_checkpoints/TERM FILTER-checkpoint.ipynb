# %% [markdown]
# # MURCHIE85 TWITTER STREAM PROCESSING
#
# ![image](https://murchie85.github.io/images/index/fab.jpg)
#
#
#
# This repo is for pulling metrics on a given keyword (best use keywords that are hashtagged) and performs a series of reporting and analysis.
#
# ## OVERVIEW
#
# - Pulls live tweets from all over twitter
# - Imports Tweepy Library
# - Consumes Twitter API
# - Desgined to be keyword driven
# - All metrics can be captured
# - No limit on Runtime (best to terminate when you want)
#
#
# ## Limitations & info
# 1. LOCATION filter is tricky
# 2. Streaming connects to the “public streams” (all public data)
#
# Example of parameter setting done in stream filter
#
# ```
# stream.filter(follow=["2211149702"])
# ```

# %% [markdown]
# # AUTHENTICATION
#
# You will need to change f variable to point to your credentials file, I save mines in a text file and split the comma. Not uploaded to this repo obviously.

# %%
import datetime


f = open("../donotgit/access.txt", "r")
keys = f.read()
f.close()
keys  = keys.split(',')
#print("Access Keys are : " + str(keys))
ACCESS_TOKEN = keys[0]
ACCESS_SECRET = keys[1]


f = open("../donotgit/consumer.txt", "r")
keys = f.read()
keys  = keys.split(',')
#print("Consumer Keys are : " + str(keys))
CONSUMER_KEY = keys[0]
CONSUMER_SECRET = keys[1]

# %% [markdown]
# # PULLING DOWN THE DATA
#
# This is where the magic happens, api authentication is set up, tweepy library is imported for the work and a class allow us to pull live data. This is appended to array for processing later.
#
# If you want to change the parameters, edit the following line:
#
# ```
# stream.filter(track=["SexStrike"],languages=["en"])
# ```
#
# *NOTE* -   this will just keep running until you force terminate, i haven't added in a terminate loop yet.

# %%
# Import the necessary package to process data in JSON format
try:
    import json
except ImportError:
    import simplejson as json

# Import the tweepy library
import tweepy

# Variables that contains the user credentials to access Twitter API 
# Captured earlier 

# Setup tweepy to authenticate with Twitter credentials:

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

# Create the api to connect to twitter with your creadentials
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)

status_array = []

class StreamListener(tweepy.StreamListener):

    def on_status(self, status):
        status_array.append(status._json)
        print(status.text)
        
    def on_error(self, status_code):
        if status_code == 420:
            return False

stream_listener = StreamListener()
stream = tweepy.Stream(auth=api.auth, listener=stream_listener)

stream.filter(track=["SexStrike"],languages=["en"])
# Out:
# RT @gspatton007: Lib “Sex Strike”
#
# This is “UNAMERICAN”
#
# Once again proves Libs are NOT
# TRUE Americans
# What’s next Boycott Apple Pie,
# Ho…
# RT @PoliticusSarah: Hey everyone upset about Alyssa Milano's #sexstrike: Thanks for helping this trend, that was the point, b/c women's liv…
# @DianaPrinceWW19 It takes a man to produce the sperm. Do you idiots even think things thru before you comment? Go a… https://t.co/ddycptXrsO
# RT @PoliticusSarah: Hey everyone upset about Alyssa Milano's #sexstrike: Thanks for helping this trend, that was the point, b/c women's liv…
# RT @usminority: Why do I get the feeling tens of millions of men are about to #Sexit the Democratic Party? https://t.co/XrKqv1iQMn
# RT @ErisofEliza: I feel like the #SexStrike is a subtle confession by straight white liberal women that they are having sex with the absolu…
# RT @ramzpaul: Women who support the #SexStrike see sex as simply something they 'give' to men to gain something in return. They do not see…
# RT @michaelbeatty3: Apparently...
# the #SexStrike has been around for awhile🤣 https://t.co/Yta1lOkaM8
# RT @EbonykKing: Here’s a WILD thought.
#
# And bear with me, it’s WILD!
#
# How about, instead of a #sexstrike,
#
# You only have sex with people yo…
# RT @RealCandaceO: From an evolutionary perspective, the radical feminist #sexstrike has the potential to save America.
#
# Yes, ladies—leave…
# RT @shannonrwatts: Rape has nothing to do with sex - it’s about hatred and power, the same causes of women being stripped of their rights.…
# RT @Nick_Clamorgan: @Alyssa_Milano strikes out w/  #SexStrike b/c only women join in who don't want babies &amp;/or hate their partners!
#
# So th…
# RT @AngryBlackLady: A woman with her sizable platform could be doing a lot more than making a few thousand people talk on Twitter.
#
# She cou…
# RT @indyrallen: So does this #SexStrike mean that feminists will be angrier than they normally are?
# RT @LVNancy: The moment you feel it move or kick -you know that is a baby -not a clump of cells.
# #AbortionIsMurder
# Society is normalizing m…
# RT @pinkk9lover: @Cocoa_Bean10 Great, less abortions then! It’s  easy for Liberal women to practice #Abstinence  ,  conservative women woul…
# RT @bethanyshondark: I genuinely feel badly that there are still women out there who think sex is something we do for men instead of a thin…
# RT @mostlybree: I'm going to pretend SexStrike isn't happening for 8,000 reasons large and small but particularly because reinforcing the u…
# RT @RealCandaceO: From an evolutionary perspective, the radical feminist #sexstrike has the potential to save America.
#
# Yes, ladies—leave…
# RT
# RT @ramzpaul: Women who support the #SexStrike see sex as simply something they 'give' to men to gain something in return. They do not see…
# RT @UnplannedMovie: JOIN US in applauding @Alyssa_Milano. What do you think? Her #sexstrike actually treats preborn lives with respect. Sex…
# RT @heyyguido: some people disagree with my views on the #sexstrike thats ok But me not having sex with my husband who fully supports me &amp;…
# RT @michellemalkin: What if Alyssa Milano called for a #SexStrike and no one came?
#
# Oh, wait. I guess that's her goal.
#
# 🤢 https://t.co/Axt…
# RT @SarahCorriher: Alyssa Milano believes she has masterminded a plan to fight an anti-abortion law: abstinence. Apparently lacking all sel…
# RT @WA_Silenced_Maj: @Alyssa_Milano will be coming out with an op-ed on her #SexStrike that liberal women will be implementing.
#
# All I can…
# RT @Arctic__char: @Larcen_ @Alyssa_Milano No what’s important here is that you’re an asshole first and foremost. #SexStrike
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-72-bfa2dac80c5b> in <module>()
#      34 stream = tweepy.Stream(auth=api.auth, listener=stream_listener)
#      35
# ---> 36 stream.filter(track=["SexStrike"],languages=["en"])
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# /Users/adammcmurchie/anaconda/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# /Users/adammcmurchie/anaconda/lib/python3.6/http/client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# /Users/adammcmurchie/anaconda/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# /Users/adammcmurchie/anaconda/lib/python3.6/http/client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# /Users/adammcmurchie/anaconda/lib/python3.6/http/client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# /Users/adammcmurchie/anaconda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     290                 raise
#     291         except OpenSSL.SSL.WantReadError:
# --> 292             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     293             if not rd:
#     294                 raise timeout('The read operation timed out')
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/urllib3/util/wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/urllib3/util/wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/urllib3/util/selectors.py in select(self, timeout)
#     511
#     512             kevent_list = _syscall_wrapper(self._kqueue.control, True,
# --> 513                                            None, max_events, timeout)
#     514
#     515             for kevent in kevent_list:
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/urllib3/util/selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# KeyboardInterrupt:

# %% [markdown]
# # PRINT AND SAVE DATA
#
# This section allows me to pull the recently mined data into a file in raw format incase i need it later.

# %%
currentDT = datetime.datetime.now()
filename = "data/streamout-" + str(currentDT) + ".txt"
reportfile = "reports/printout-"+ str(currentDT) + ".txt"
print(filename)

with open(filename, 'w') as f:
    for item in status_array:
        f.write("%s\n" % item)
f.close()
# Out:
# data/streamout-2019-05-12 15:58:29.856001.txt

# %% [markdown]
# # STREAM METADATA

# %%
print('Number of records')
print(len(status_array))
print('')
print('The data keys are : ')
print(status_array[0].keys())
print('')
print('An example element looks like: ')
# Out:
# Number of records
# 113
#
# The data keys are :
# dict_keys(['created_at', 'id', 'id_str', 'text', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'quoted_status_id', 'quoted_status_id_str', 'quoted_status', 'quoted_status_permalink', 'is_quote_status', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'])
#
# An example element looks like:

# %% [markdown]
# # REPORT GENERATION

# %%
REPORTCOUNT = 0
with open(reportfile, 'w') as f:
    for y in range(0, len(status_array)):
        REPORTCOUNT = REPORTCOUNT + 1
        f.write('************************************************************\n')
        f.write(status_array[y]['text'])
        f.write('------------------------------\n')
        f.write(status_array[y]['created_at'])
        f.write('------------------------------\n')
        f.write(status_array[y]['user']['name'])
        f.write('------------------------------\n')
        f.write(str(status_array[y]['user']['location']))
        f.write('------------------------------\n')
        f.write(str(status_array[y]['user']['description']))
        f.write('--------------REPLY COUNT----------------\n|')
        f.write(str(status_array[y]['reply_count']))
        f.write('--------------RETWEET COUNT----------------\n')
        f.write(str(status_array[y]['retweet_count']))
        f.write('--------------RETWEETED?----------------\n')
        f.write(str(status_array[y]['retweeted']))
        f.write('--------------RETWEET COUNT----------------\n')
        f.write(str(status_array[y]['retweet_count']))
        f.write('--------------FAVOURITED----------------\n')
        f.write(str(status_array[y]['favorited']))
        f.write('--------------FAVOURITE COUNT----------------\n')
        f.write(str(status_array[y]['favorite_count']))
        f.write('\n')
        f.write('\n')
    f.write('number of records are : ')
    f.write(str(REPORTCOUNT))
        
f.close()
    
    
    
    
    

    
    
    
    
    
    
for x in range(0, len(status_array)):
    print('************************************************************')
    print(status_array[x]['text'])
    print('------------------------------')
    print(status_array[x]['created_at'])
    print('------------------------------')
    print(status_array[x]['user']['name'])
    print('------------------------------')
    print(status_array[x]['user']['location'])
    print('------------------------------')
    print(status_array[x]['user']['description'])
    print('--------------REPLY COUNT----------------')
    print(status_array[x]['reply_count'])
    print('--------------RETWEET COUNT----------------')
    print(status_array[x]['retweet_count'])
    print('--------------RETWEETED?----------------')
    print(status_array[x]['retweeted'])
    print('--------------RETWEET COUNT----------------')
    print(status_array[x]['retweet_count'])
    print('--------------FAVOURITED----------------')
    print(status_array[x]['favorited'])
    print('--------------FAVOURITE COUNT----------------')
    print(status_array[x]['favorite_count'])
    print('')
    print('')
# Out:
# ************************************************************
# RT @gspatton007: Lib “Sex Strike”
#
# This is “UNAMERICAN”
#
# Once again proves Libs are NOT
# TRUE Americans
# What’s next Boycott Apple Pie,
# Ho…
# ------------------------------
# Sun May 12 14:57:10 +0000 2019
# ------------------------------
# Rebecca Downs
# ------------------------------
# None
# ------------------------------
# 🇺🇸 Eventhough my THOUGHTS are NOT exactly your THOUGHTS.We keep praying in ONE ACCORD moving MOUNTIANS!  SECRETS are being REVEALED.🇺🇸MAGA AMERICAFIRST💯
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @PoliticusSarah: Hey everyone upset about Alyssa Milano's #sexstrike: Thanks for helping this trend, that was the point, b/c women's liv…
# ------------------------------
# Sun May 12 14:57:10 +0000 2019
# ------------------------------
# Sydney Feinsmith
# ------------------------------
# Atlanta, GA
# ------------------------------
# just an industrial engineering student. mostly retweet and reply. #ERANow #ImpeachmentNOW
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# @DianaPrinceWW19 It takes a man to produce the sperm. Do you idiots even think things thru before you comment? Go a… https://t.co/ddycptXrsO
# ------------------------------
# Sun May 12 14:57:12 +0000 2019
# ------------------------------
# Never Vote Democrat Again
# ------------------------------
# None
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @PoliticusSarah: Hey everyone upset about Alyssa Milano's #sexstrike: Thanks for helping this trend, that was the point, b/c women's liv…
# ------------------------------
# Sun May 12 14:57:12 +0000 2019
# ------------------------------
# gaslighting should not be a real thing
# ------------------------------
# Wichita, KS
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @usminority: Why do I get the feeling tens of millions of men are about to #Sexit the Democratic Party? https://t.co/XrKqv1iQMn
# ------------------------------
# Sun May 12 14:57:13 +0000 2019
# ------------------------------
# Jacquie Camera
# ------------------------------
# None
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @ErisofEliza: I feel like the #SexStrike is a subtle confession by straight white liberal women that they are having sex with the absolu…
# ------------------------------
# Sun May 12 14:57:13 +0000 2019
# ------------------------------
# kate
# ------------------------------
# Bristol
# ------------------------------
# library punk • @speedskaterband 🎤 • 🌈 she/her
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @ramzpaul: Women who support the #SexStrike see sex as simply something they 'give' to men to gain something in return. They do not see…
# ------------------------------
# Sun May 12 14:57:14 +0000 2019
# ------------------------------
# LeeLee ⏳ BuildKate'sWall #ClearGenFlynn
# ------------------------------
# None
# ------------------------------
# .#Nationalist  Fed up EX Lib Girl.Dangerously Dedicated to Starving the Beast . to Q?..or Not to Q?  #MAGA  @leeleejay1818  http://gab.ai/leeleemunster
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @michaelbeatty3: Apparently...
# the #SexStrike has been around for awhile🤣 https://t.co/Yta1lOkaM8
# ------------------------------
# Sun May 12 14:57:14 +0000 2019
# ------------------------------
# Carrie ❤️ America 🇺🇸
# ------------------------------
# Idaho, USA
# ------------------------------
# “I prefer dangerous freedom over peaceful slavery” T. Jefferson #WWG1WGA #2A Proud Wife of 💜Combat Vet Welcome🏠Vietnam Vets! 🇺🇸🤝🇮🇱 #Trump2020
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @EbonykKing: Here’s a WILD thought.
#
# And bear with me, it’s WILD!
#
# How about, instead of a #sexstrike,
#
# You only have sex with people yo…
# ------------------------------
# Sun May 12 14:57:14 +0000 2019
# ------------------------------
# AMAZINACE
# ------------------------------
# 55 Secret st.
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @RealCandaceO: From an evolutionary perspective, the radical feminist #sexstrike has the potential to save America.
#
# Yes, ladies—leave…
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# @Alyssa_Milano Try reading the article first and see how unsurprisingly ineffective a sexstrike would be.
# ------------------------------
# Sun May 12 14:57:25 +0000 2019
# ------------------------------
# Vic Temless 🌐
# ------------------------------
# Los Angeles, CA
# ------------------------------
# How to buy your own personal delinquent charged-off debt for just pennies on the dollar.
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @spookperson: you’ve got to hand it to alyssa for throwing the trans community a bone and courting t*rfs in the space of three sentences…
# ------------------------------
# Sun May 12 14:57:25 +0000 2019
# ------------------------------
# Bill Abney
# ------------------------------
# san francisco bay area
# ------------------------------
# not even a person (he/him)
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @ScottPresler: Liberal women having a #SexStrike means
#
# conservative women will be having more babies.
#
# I fully support this pro-life…
# ------------------------------
# Sun May 12 14:57:26 +0000 2019
# ------------------------------
# Mary8888
# ------------------------------
# New Jersey, USA
# ------------------------------
# Mom, wife,workout enthusiast, Born in Brooklyn. Still waiting for the wall. Republicans get me! MAGA. Love my country 💪🤔🍷🇺🇸
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @PoliticusSarah: Hey everyone upset about Alyssa Milano's #sexstrike: Thanks for helping this trend, that was the point, b/c women's liv…
# ------------------------------
# Sun May 12 14:57:26 +0000 2019
# ------------------------------
# Joan Tetz
# ------------------------------
# Taylor, MI
# ------------------------------
# Small business owner, love for all people and family. #RegisterToVote #KeepFamiliesTogether #Resistance #BanBumpStocks #BlackLivesMatter #FamiliesBelongTogether
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @KristySwansonXO: Wow! Today’s my lucky day 😂🤣 https://t.co/oq1oOpGONW
# ------------------------------
# Sun May 12 14:57:28 +0000 2019
# ------------------------------
# Trump2020
# ------------------------------
# United States
# ------------------------------
# MAGA!
# TRUMP IS OUR PRESIDENT!
# CROOKED HILLARY LOVING LIBERALS NEED TO GET OVER IT!
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @Alyssa_Milano: Our reproductive rights are being erased.
#
# Until women have legal control over our own bodies we just cannot risk pregna…
# ------------------------------
# Sun May 12 14:57:28 +0000 2019
# ------------------------------
# Taunya
# ------------------------------
# Get. Cincinnati, OH
# ------------------------------
# natural born punker. artistic music lover. strong willed with an open mind. not much of a filter kinda girrl!🤘
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @Femmefeministe: 1. Erasing LGBTQIA folks from the discussion of abortion and centering solutions (if you can call this a solution) arou…
# ------------------------------
# Sun May 12 14:57:28 +0000 2019
# ------------------------------
# ¯\_(ツ)_/¯
# ------------------------------
# Canada
# ------------------------------
# i can sing from blee to bleh//better at playing piano than Schoenberg//(she/her)
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @V_actually: So the prism through which you view sex is about "being on strike" ?
#
# You see sex as a tool to gain power and not as an exp…
# ------------------------------
# Sun May 12 14:57:29 +0000 2019
# ------------------------------
# Dave Neill
# ------------------------------
# Devon, England
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# The liberal men should counter #SexStrike with #workstrike ... oh wait ...
# ------------------------------
# Sun May 12 14:57:30 +0000 2019
# ------------------------------
# Steve Heath - toxic male
# ------------------------------
# underneath Golden Corral
# ------------------------------
# REAL native American, swim coach and employer of legal immigrants.
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @schemaly: I’m also not a fan of the #sexstrike, for the many reasons others are citing. Besides, sex is just fun. So, if we are going t…
# ------------------------------
# Sun May 12 14:57:30 +0000 2019
# ------------------------------
# Irene T
# ------------------------------
# Victorville,  California
# ------------------------------
# Elementary Music teacher.  I love writing songs and watching my students write them too. I also love wildlife, inc. snakes.
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @andreas_racz: I know what ur saying but ur kind of proving their point if u don’t have sex you won’t get pregnant https://t.co/lfwyBKMP…
# ------------------------------
# Sun May 12 14:57:32 +0000 2019
# ------------------------------
# guppy goldberg
# ------------------------------
# pawnee
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @heyyguido: some people disagree with my views on the #sexstrike thats ok But me not having sex with my husband who fully supports me &amp;…
# ------------------------------
# Sun May 12 14:58:18 +0000 2019
# ------------------------------
# ¿Que?
# ------------------------------
# Orangevale, CA
# ------------------------------
# InfoSec person (he/him). Cat? Adventures in parenting. Cat? Thoughts and opinions still regrettably my own. Cat? Myers-Briggs: BOFH
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @michellemalkin: What if Alyssa Milano called for a #SexStrike and no one came?
#
# Oh, wait. I guess that's her goal.
#
# 🤢 https://t.co/Axt…
# ------------------------------
# Sun May 12 14:58:18 +0000 2019
# ------------------------------
# RICH LIMATO
# ------------------------------
# None
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @SarahCorriher: Alyssa Milano believes she has masterminded a plan to fight an anti-abortion law: abstinence. Apparently lacking all sel…
# ------------------------------
# Sun May 12 14:58:18 +0000 2019
# ------------------------------
# Another Epic Day
# ------------------------------
# None
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @WA_Silenced_Maj: @Alyssa_Milano will be coming out with an op-ed on her #SexStrike that liberal women will be implementing.
#
# All I can…
# ------------------------------
# Sun May 12 14:58:19 +0000 2019
# ------------------------------
# Tamara 😎
# ------------------------------
# Dallas, TX
# ------------------------------
# I LOVE JESUS ,AMERICA, DONALD TRUMPERS,
# PATRIOTS, PRO LIFERS, VETS, FREEDOM, OH YEAH, HOT DOGS, APPLE PIE, AND CHEVROLET. OH AND BACON!! #MAGA #TCOT
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @Arctic__char: @Larcen_ @Alyssa_Milano No what’s important here is that you’re an asshole first and foremost. #SexStrike
# ------------------------------
# Sun May 12 14:58:20 +0000 2019
# ------------------------------
# Larcen 🇺🇸🏳️‍🌈
# ------------------------------
# Van down by the river
# ------------------------------
# Support law enforcement, 🏳️‍🌈 LBGT, found I was loved by the people I was told hated me and hated by the ones who controlled me.
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0

# %%
status_array[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun May 12 13:07:14 +0000 2019',
#  'entities': {'hashtags': [{'indices': [73, 83], 'text': 'sexstrike'}],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 878247600096509952,
#     'id_str': '878247600096509952',
#     'indices': [3, 16],
#     'name': 'Candace Owens',
#     'screen_name': 'RealCandaceO'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1127560866935656450,
#  'id_str': '1127560866935656450',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat May 11 19:05:05 +0000 2019',
#   'entities': {'hashtags': [{'indices': [55, 65], 'text': 'sexstrike'}],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1127288537219354624',
#      'indices': [117, 140],
#      'url': 'https://t.co/i21dPAbtlR'}],
#    'user_mentions': []},
#   'extended_tweet': {'display_text_range': [0, 265],
#    'entities': {'hashtags': [{'indices': [55, 65], 'text': 'sexstrike'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'full_text': 'From an evolutionary perspective, the radical feminist #sexstrike has the potential to save America. \n\nYes, ladies—leave the terrible bondage of procreation to us horrible conservatives. \n\nConsider me a dear ally, friend and mentor on your commitment to abstinence.'},
#   'favorite_count': 42504,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 1127288537219354624,
#   'id_str': '1127288537219354624',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'quote_count': 691,
#   'reply_count': 1955,
#   'retweet_count': 10491,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'From an evolutionary perspective, the radical feminist #sexstrike has the potential to save America. \n\nYes, ladies—… https://t.co/i21dPAbtlR',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jun 23 13:45:19 +0000 2017',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Black People Don’t Have to be Democrats. #BLEXIT',
#    'favourites_count': 18138,
#    'follow_request_sent': None,
#    'followers_count': 1362620,
#    'following': None,
#    'friends_count': 407,
#    'geo_enabled': False,
#    'id': 878247600096509952,
#    'id_str': '878247600096509952',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 4315,
#    'location': 'New York, USA',
#    'name': 'Candace Owens',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/878247600096509952/1541810444',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1031586214548267009/oFJ3JNLB_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1031586214548267009/oFJ3JNLB_normal.jpg',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'RealCandaceO',
#    'statuses_count': 2720,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://www.blexit.com',
#    'utc_offset': None,
#    'verified': True}},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'text': 'RT @RealCandaceO: From an evolutionary perspective, the radical feminist #sexstrike has the potential to save America. \n\nYes, ladies—leave…',
#  'timestamp_ms': '1557666434402',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Sat Jan 14 01:20:26 +0000 2017',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'Living among the Snowflakes on the Oregon Coast. Happily married to my best friend. NOT looking for dates.  #NRA  #KAG #Trump2020 #BUILDTHEWALL #2ThumbsUPTrain',
#   'favourites_count': 85839,
#   'follow_request_sent': None,
#   'followers_count': 7003,
#   'following': None,
#   'friends_count': 6996,
#   'geo_enabled': True,
#   'id': 820078082786611201,
#   'id_str': '820078082786611201',
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 10,
#   'location': 'Pacific Northwest',
#   'name': 'DebLF ☝☝',
#   'notifications': None,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': '',
#   'profile_background_image_url_https': '',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/820078082786611201/1547509109',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/964519914760413184/fleMJYP__normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/964519914760413184/fleMJYP__normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'DebFerg9',
#   'statuses_count': 9242,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': None,
#   'verified': False}}

# %%
status_array[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun May 12 13:07:14 +0000 2019',
#  'entities': {'hashtags': [{'indices': [73, 83], 'text': 'sexstrike'}],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 878247600096509952,
#     'id_str': '878247600096509952',
#     'indices': [3, 16],
#     'name': 'Candace Owens',
#     'screen_name': 'RealCandaceO'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1127560866935656450,
#  'id_str': '1127560866935656450',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': False,
#  'lang': 'en',
#  'place': None,
#  'quote_count': 0,
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat May 11 19:05:05 +0000 2019',
#   'entities': {'hashtags': [{'indices': [55, 65], 'text': 'sexstrike'}],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1127288537219354624',
#      'indices': [117, 140],
#      'url': 'https://t.co/i21dPAbtlR'}],
#    'user_mentions': []},
#   'extended_tweet': {'display_text_range': [0, 265],
#    'entities': {'hashtags': [{'indices': [55, 65], 'text': 'sexstrike'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'full_text': 'From an evolutionary perspective, the radical feminist #sexstrike has the potential to save America. \n\nYes, ladies—leave the terrible bondage of procreation to us horrible conservatives. \n\nConsider me a dear ally, friend and mentor on your commitment to abstinence.'},
#   'favorite_count': 42504,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 1127288537219354624,
#   'id_str': '1127288537219354624',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'quote_count': 691,
#   'reply_count': 1955,
#   'retweet_count': 10491,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'From an evolutionary perspective, the radical feminist #sexstrike has the potential to save America. \n\nYes, ladies—… https://t.co/i21dPAbtlR',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Fri Jun 23 13:45:19 +0000 2017',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'Black People Don’t Have to be Democrats. #BLEXIT',
#    'favourites_count': 18138,
#    'follow_request_sent': None,
#    'followers_count': 1362620,
#    'following': None,
#    'friends_count': 407,
#    'geo_enabled': False,
#    'id': 878247600096509952,
#    'id_str': '878247600096509952',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 4315,
#    'location': 'New York, USA',
#    'name': 'Candace Owens',
#    'notifications': None,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/878247600096509952/1541810444',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1031586214548267009/oFJ3JNLB_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1031586214548267009/oFJ3JNLB_normal.jpg',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'RealCandaceO',
#    'statuses_count': 2720,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://www.blexit.com',
#    'utc_offset': None,
#    'verified': True}},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'text': 'RT @RealCandaceO: From an evolutionary perspective, the radical feminist #sexstrike has the potential to save America. \n\nYes, ladies—leave…',
#  'timestamp_ms': '1557666434402',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Sat Jan 14 01:20:26 +0000 2017',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'Living among the Snowflakes on the Oregon Coast. Happily married to my best friend. NOT looking for dates.  #NRA  #KAG #Trump2020 #BUILDTHEWALL #2ThumbsUPTrain',
#   'favourites_count': 85839,
#   'follow_request_sent': None,
#   'followers_count': 7003,
#   'following': None,
#   'friends_count': 6996,
#   'geo_enabled': True,
#   'id': 820078082786611201,
#   'id_str': '820078082786611201',
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 10,
#   'location': 'Pacific Northwest',
#   'name': 'DebLF ☝☝',
#   'notifications': None,
#   'profile_background_color': 'F5F8FA',
#   'profile_background_image_url': '',
#   'profile_background_image_url_https': '',
#   'profile_background_tile': False,
#   'profile_banner_url': 'https://pbs.twimg.com/profile_banners/820078082786611201/1547509109',
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/964519914760413184/fleMJYP__normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/964519914760413184/fleMJYP__normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'DebFerg9',
#   'statuses_count': 9242,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': None,
#   'verified': False}}

# %%
count = 0
for z in range(0, len(status_array)):
    if "right" in str(status_array[z]): 
        count = count + 1
        print('found')
    
print(count)
# Out:
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# found
# 73

# %% [markdown]
# #  FIELDS OF INTEREST
# - text
#
#
# - user
# - user.description
# - user.followers_count

# %%
status_array[0]
# Out:
# {'contributors_enabled': False,
#  'created_at': 'Sat Jan 14 01:20:26 +0000 2017',
#  'default_profile': True,
#  'default_profile_image': False,
#  'description': 'Living among the Snowflakes on the Oregon Coast. Happily married to my best friend. NOT looking for dates.  #NRA  #KAG #Trump2020 #BUILDTHEWALL #2ThumbsUPTrain',
#  'favourites_count': 85839,
#  'follow_request_sent': None,
#  'followers_count': 7003,
#  'following': None,
#  'friends_count': 6996,
#  'geo_enabled': True,
#  'id': 820078082786611201,
#  'id_str': '820078082786611201',
#  'is_translator': False,
#  'lang': 'en',
#  'listed_count': 10,
#  'location': 'Pacific Northwest',
#  'name': 'DebLF ☝☝',
#  'notifications': None,
#  'profile_background_color': 'F5F8FA',
#  'profile_background_image_url': '',
#  'profile_background_image_url_https': '',
#  'profile_background_tile': False,
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/820078082786611201/1547509109',
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/964519914760413184/fleMJYP__normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/964519914760413184/fleMJYP__normal.jpg',
#  'profile_link_color': '1DA1F2',
#  'profile_sidebar_border_color': 'C0DEED',
#  'profile_sidebar_fill_color': 'DDEEF6',
#  'profile_text_color': '333333',
#  'profile_use_background_image': True,
#  'protected': False,
#  'screen_name': 'DebFerg9',
#  'statuses_count': 9242,
#  'time_zone': None,
#  'translator_type': 'none',
#  'url': None,
#  'utc_offset': None,
#  'verified': False}

# %%
# Search for latest tweets about "#nlproc"
tweets = tweepy.Cursor(api.search, q='#nlproc')

# %%
tweets

# %%
class tweetstream(tweepy.StreamListener):

    def on_status(self, status):
        status_array.append(status._json)
        print(status.text)
        
    def on_error(self, status_code):
        if status_code == 420:
            return False

tweet_stream = tweetstream()
stream = tweepy.Stream(auth=api.auth, listener=tweet_stream)

stream.filter(track=["SexStrike"],languages=["en"])
# Out:
# RT @ErisofEliza: I feel like the #SexStrike is a subtle confession by straight white liberal women that they are having sex with the absolu…
# Using sex as a weapon is sooooooo #progressive.  Just stop @Alyssa_Milano.  You’re drunk with stupidity.
# You've taught her well, Foo. https://t.co/n7MAD7EufF
# RT @KatTheHammer1: Bette Midler joins sex strike protest....😏
#
# #sexstrike 😂😂 https://t.co/myX6Yuszto
# RT @mostlybree: I'm going to pretend SexStrike isn't happening for 8,000 reasons large and small but particularly because reinforcing the u…
# RT @GymCoachMac: Can't cuz they're on #SexStrike https://t.co/hD396oSyZg
# RT @Imamofpeace: Feminists promoting the #SexStrike make me laugh. Don’t they know that according to Sharia Law (applied in 100s of courts…
# RT @KayFellowz: Who would have thought abortion activists would end up doing our work for us?
# Ready to see those abortion numbers go way d…
# RT @IamPrairiestorm: @Alyssa_Milano Ummmmm why dont you just use a condom? Or other contraceptive?
#
# Sex isn't related to pregnancy unless y…
# RT @Alyssa_Milano: Our reproductive rights are being erased.
#
# Until women have legal control over our own bodies we just cannot risk pregna…
# RT @RealTimBlack: My wife and I could careless about what Alyssa Milano has to say about our sex life besides we're already on a #SexStrike…
# RT @FaithNaff: A #SexStrike is not the answer because.
#
# - It insinuates women are a sex supply and men are a sex demand.
#
# - It erases queer…
# RT @ThePrettyPixie: @TMZ AM wants women to have to suffer by not having sex with their partners, which will only ruin relationships! She wa…
# @dataminer_1999 @dlmreport @thefool_wa @Alyssa_Milano Two points on #SexStrike:
# 1) #SexStrike is a universal call f… https://t.co/PWcM9fQgin
# RT @ErisofEliza: I feel like the #SexStrike is a subtle confession by straight white liberal women that they are having sex with the absolu…
# I SAID LIKE
# RT @HawaiiDelilah: My view on the #sexstrike  is simple. Don't have sex with anyone who is anti-choice. Understand that at the core it is a…
# @RedTRaccoon Many female resisters do not support the divisive idea of a #SexStrike we may not be your personal fri… https://t.co/L5qOBQ2KQ2
# RT @blueskies366: #SexStrike is anyone actually having sex with antichoice people ? Like ever?
#
# What we may need is a mass walkout by all p…
# RT @realhublife: WE WON!!!!
#
# They're gonna stop reproducing!!!
#
# (Also, I'm 99% sure Alyssa Milano's husband is cheating) https://t.co/MmGUN…
# RT @SarahCorriher: Alyssa Milano believes she has masterminded a plan to fight an anti-abortion law: abstinence. Apparently lacking all sel…
# RT @staceydash: Oh good! No premarital sex. And no more abortions. Good girls–you’re  on the right track! https://t.co/OXeHag4Mnw
# RT @sadiemegin: Thank you for proving that #abstinence is the 100% effective way of preventing pregnancy.
#
# People who cannot be adult enoug…
# RT @RationalMale: #SexStrike once again proves a long time Red Pill fundamental;
#
# Women’s moral compass is in their vaginas.
# https://t.co/t…
# RT @BenBurgis: I have an even better idea than a #sexstrike. What if everyone went on strike but.....hear me out.....from work instead of s…
# ---------------------------------------------------------------------------
# WantReadError                             Traceback (most recent call last)
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     279         try:
# --> 280             return self.connection.recv_into(*args, **kwargs)
#     281         except OpenSSL.SSL.SysCallError as e:
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1546             result = _lib.SSL_read(self._ssl, buf, nbytes)
# -> 1547         self._raise_ssl_error(self._ssl, result)
#    1548
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1352         if error == _lib.SSL_ERROR_WANT_READ:
# -> 1353             raise WantReadError()
#    1354         elif error == _lib.SSL_ERROR_WANT_WRITE:
#
# WantReadError:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-c45726c57073> in <module>()
#      12 stream = tweepy.Stream(auth=api.auth, listener=tweet_stream)
#      13
# ---> 14 stream.filter(track=["SexStrike"],languages=["en"])
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/tweepy/streaming.py in filter(self, follow, track, is_async, locations, stall_warnings, languages, encoding, filter_level)
#     451             self.body['filter_level'] = filter_level.encode(encoding)
#     452         self.session.params = {'delimited': 'length'}
# --> 453         self._start(is_async)
#     454
#     455     def sitestream(self, follow, stall_warnings=False,
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/tweepy/streaming.py in _start(self, is_async)
#     366             self._thread.start()
#     367         else:
# --> 368             self._run()
#     369
#     370     def on_closed(self, resp):
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/tweepy/streaming.py in _run(self)
#     267                     self.snooze_time = self.snooze_time_step
#     268                     self.listener.on_connect()
# --> 269                     self._read_loop(resp)
#     270             except (Timeout, ssl.SSLError) as exc:
#     271                 # This is still necessary, as a SSLError can actually be
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/tweepy/streaming.py in _read_loop(self, resp)
#     317             length = 0
#     318             while not resp.raw.closed:
# --> 319                 line = buf.read_line()
#     320                 stripped_line = line.strip() if line else line # line is sometimes None so we need to check here
#     321                 if not stripped_line:
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/tweepy/streaming.py in read_line(self, sep)
#     179             else:
#     180                 start = len(self._buffer)
# --> 181             self._buffer += self._stream.read(self._chunk_size)
#     182         return six.b('')
#     183
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/urllib3/response.py in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# /Users/adammcmurchie/anaconda/lib/python3.6/http/client.py in read(self, amt)
#     447             # Amount is given, implement using readinto
#     448             b = bytearray(amt)
# --> 449             n = self.readinto(b)
#     450             return memoryview(b)[:n].tobytes()
#     451         else:
#
# /Users/adammcmurchie/anaconda/lib/python3.6/http/client.py in readinto(self, b)
#     481
#     482         if self.chunked:
# --> 483             return self._readinto_chunked(b)
#     484
#     485         if self.length is not None:
#
# /Users/adammcmurchie/anaconda/lib/python3.6/http/client.py in _readinto_chunked(self, b)
#     576         try:
#     577             while True:
# --> 578                 chunk_left = self._get_chunk_left()
#     579                 if chunk_left is None:
#     580                     return total_bytes
#
# /Users/adammcmurchie/anaconda/lib/python3.6/http/client.py in _get_chunk_left(self)
#     544                 self._safe_read(2)  # toss the CRLF at the end of the chunk
#     545             try:
# --> 546                 chunk_left = self._read_next_chunk_size()
#     547             except ValueError:
#     548                 raise IncompleteRead(b'')
#
# /Users/adammcmurchie/anaconda/lib/python3.6/http/client.py in _read_next_chunk_size(self)
#     504     def _read_next_chunk_size(self):
#     505         # Read the next chunk size from the file
# --> 506         line = self.fp.readline(_MAXLINE + 1)
#     507         if len(line) > _MAXLINE:
#     508             raise LineTooLong("chunk size")
#
# /Users/adammcmurchie/anaconda/lib/python3.6/socket.py in readinto(self, b)
#     584         while True:
#     585             try:
# --> 586                 return self._sock.recv_into(b)
#     587             except timeout:
#     588                 self._timeout_occurred = True
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     290                 raise
#     291         except OpenSSL.SSL.WantReadError:
# --> 292             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     293             if not rd:
#     294                 raise timeout('The read operation timed out')
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/urllib3/util/wait.py in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/urllib3/util/wait.py in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/urllib3/util/selectors.py in select(self, timeout)
#     511
#     512             kevent_list = _syscall_wrapper(self._kqueue.control, True,
# --> 513                                            None, max_events, timeout)
#     514
#     515             for kevent in kevent_list:
#
# /Users/adammcmurchie/anaconda/lib/python3.6/site-packages/urllib3/util/selectors.py in _syscall_wrapper(func, _, *args, **kwargs)
#      62         and recalculate their timeouts. """
#      63         try:
# ---> 64             return func(*args, **kwargs)
#      65         except (OSError, IOError, select.error) as e:
#      66             errcode = None
#
# KeyboardInterrupt:

# %%
len(status_array)
# Out:
# 175

# %%
status_array[1]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun May 12 13:07:14 +0000 2019',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 52338305,
#     'id_str': '52338305',
#     'indices': [3, 14],
#     'name': 'Brandon Straka',
#     'screen_name': 'usminority'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1127560868743536641,
#  'id_str': '1127560868743536641',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': True,
#  'lang': 'en',
#  'place': None,
#  'quote_count': 0,
#  'quoted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat May 11 02:40:38 +0000 2019',
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1127040792281767936',
#      'indices': [117, 140],
#      'url': 'https://t.co/TsIN3KUQM7'}],
#    'user_mentions': []},
#   'extended_tweet': {'display_text_range': [0, 230],
#    'entities': {'hashtags': [{'indices': [207, 217], 'text': 'SexStrike'}],
#     'media': [{'display_url': 'pic.twitter.com/uOgN4FKwpg',
#       'expanded_url': 'https://twitter.com/Alyssa_Milano/status/1127040792281767936/photo/1',
#       'id': 1127040785952546817,
#       'id_str': '1127040785952546817',
#       'indices': [231, 254],
#       'media_url': 'http://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#       'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1582},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 927},
#        'small': {'h': 680, 'resize': 'fit', 'w': 525},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/uOgN4FKwpg'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/uOgN4FKwpg',
#       'expanded_url': 'https://twitter.com/Alyssa_Milano/status/1127040792281767936/photo/1',
#       'id': 1127040785952546817,
#       'id_str': '1127040785952546817',
#       'indices': [231, 254],
#       'media_url': 'http://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#       'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1582},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 927},
#        'small': {'h': 680, 'resize': 'fit', 'w': 525},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/uOgN4FKwpg'}]},
#    'full_text': 'Our reproductive rights are being erased.\n\nUntil women have legal control over our own bodies we just cannot risk pregnancy. \n\nJOIN ME by not having sex until we get bodily autonomy back.\n\nI’m calling for a #SexStrike. Pass it on. https://t.co/uOgN4FKwpg'},
#   'favorite_count': 39260,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 1127040792281767936,
#   'id_str': '1127040792281767936',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'quote_count': 20708,
#   'reply_count': 39615,
#   'retweet_count': 13319,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Our reproductive rights are being erased.\n\nUntil women have legal control over our own bodies we just cannot risk p… https://t.co/TsIN3KUQM7',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Mar 26 00:34:20 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '🇺🇸 Check out @sorrynotsorry @PatNotPart and @NoRA4USA Please follow my other accounts for career updates @AlyssaDotCom @TouchByAM #NoRA',
#    'favourites_count': 18131,
#    'follow_request_sent': None,
#    'followers_count': 3567522,
#    'following': None,
#    'friends_count': 3959,
#    'geo_enabled': True,
#    'id': 26642006,
#    'id_str': '26642006',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 37542,
#    'location': 'Los Angeles',
#    'name': 'Alyssa Milano',
#    'notifications': None,
#    'profile_background_color': '260808',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26642006/1557181528',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1126230170522644480/jMfg6Vdd_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1126230170522644480/jMfg6Vdd_normal.jpg',
#    'profile_link_color': 'E81C4F',
#    'profile_sidebar_border_color': '77BF56',
#    'profile_sidebar_fill_color': 'A5C44F',
#    'profile_text_color': 'EBE18F',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Alyssa_Milano',
#    'statuses_count': 56511,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://alyssa.com',
#    'utc_offset': None,
#    'verified': True}},
#  'quoted_status_id': 1127040792281767936,
#  'quoted_status_id_str': '1127040792281767936',
#  'quoted_status_permalink': {'display': 'twitter.com/alyssa_milano/…',
#   'expanded': 'https://twitter.com/alyssa_milano/status/1127040792281767936',
#   'url': 'https://t.co/XrKqv1iQMn'},
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat May 11 05:54:33 +0000 2019',
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1127089592367104001',
#      'indices': [116, 139],
#      'url': 'https://t.co/8rz0IZkKWa'}],
#    'user_mentions': []},
#   'extended_tweet': {'display_text_range': [0, 274],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/alyssa_milano/…',
#       'expanded_url': 'https://twitter.com/alyssa_milano/status/1127040792281767936',
#       'indices': [275, 298],
#       'url': 'https://t.co/XrKqv1iQMn'}],
#     'user_mentions': [{'id': 26642006,
#       'id_str': '26642006',
#       'indices': [177, 191],
#       'name': 'Alyssa Milano',
#       'screen_name': 'Alyssa_Milano'},
#      {'id': 25073877,
#       'id_str': '25073877',
#       'indices': [214, 230],
#       'name': 'Donald J. Trump',
#       'screen_name': 'realDonaldTrump'},
#      {'id': 21148293,
#       'id_str': '21148293',
#       'indices': [237, 250],
#       'name': 'Kathy Griffin',
#       'screen_name': 'kathygriffin'}]},
#    'full_text': 'This is the greatest tweet that has ever been put forth to humanity. \n\nMy eyes will never again gaze upon anything on twitter as stupidity-rich and robust with idiocy as this. \n@Alyssa_Milano just broke me the way @realDonaldTrump broke @kathygriffin. \n\nI can die happy now. https://t.co/XrKqv1iQMn'},
#   'favorite_count': 14129,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 1127089592367104001,
#   'id_str': '1127089592367104001',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'place': {'attributes': {},
#    'bounding_box': {'coordinates': [[[-115.209254, 35.984784],
#       [-115.209254, 36.137145],
#       [-115.061076, 36.137145],
#       [-115.061076, 35.984784]]],
#     'type': 'Polygon'},
#    'country': 'United States',
#    'country_code': 'US',
#    'full_name': 'Paradise, NV',
#    'id': '8fa6d7a33b83ef26',
#    'name': 'Paradise',
#    'place_type': 'city',
#    'url': 'https://api.twitter.com/1.1/geo/id/8fa6d7a33b83ef26.json'},
#   'possibly_sensitive': False,
#   'quote_count': 483,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat May 11 02:40:38 +0000 2019',
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1127040792281767936',
#       'indices': [117, 140],
#       'url': 'https://t.co/TsIN3KUQM7'}],
#     'user_mentions': []},
#    'extended_tweet': {'display_text_range': [0, 230],
#     'entities': {'hashtags': [{'indices': [207, 217], 'text': 'SexStrike'}],
#      'media': [{'display_url': 'pic.twitter.com/uOgN4FKwpg',
#        'expanded_url': 'https://twitter.com/Alyssa_Milano/status/1127040792281767936/photo/1',
#        'id': 1127040785952546817,
#        'id_str': '1127040785952546817',
#        'indices': [231, 254],
#        'media_url': 'http://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#        'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1582},
#         'medium': {'h': 1200, 'resize': 'fit', 'w': 927},
#         'small': {'h': 680, 'resize': 'fit', 'w': 525},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/uOgN4FKwpg'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'extended_entities': {'media': [{'display_url': 'pic.twitter.com/uOgN4FKwpg',
#        'expanded_url': 'https://twitter.com/Alyssa_Milano/status/1127040792281767936/photo/1',
#        'id': 1127040785952546817,
#        'id_str': '1127040785952546817',
#        'indices': [231, 254],
#        'media_url': 'http://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#        'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1582},
#         'medium': {'h': 1200, 'resize': 'fit', 'w': 927},
#         'small': {'h': 680, 'resize': 'fit', 'w': 525},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/uOgN4FKwpg'}]},
#     'full_text': 'Our reproductive rights are being erased.\n\nUntil women have legal control over our own bodies we just cannot risk pregnancy. \n\nJOIN ME by not having sex until we get bodily autonomy back.\n\nI’m calling for a #SexStrike. Pass it on. https://t.co/uOgN4FKwpg'},
#    'favorite_count': 39260,
#    'favorited': False,
#    'filter_level': 'low',
#    'geo': None,
#    'id': 1127040792281767936,
#    'id_str': '1127040792281767936',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'quote_count': 20708,
#    'reply_count': 39615,
#    'retweet_count': 13319,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Our reproductive rights are being erased.\n\nUntil women have legal control over our own bodies we just cannot risk p… https://t.co/TsIN3KUQM7',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Mar 26 00:34:20 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '🇺🇸 Check out @sorrynotsorry @PatNotPart and @NoRA4USA Please follow my other accounts for career updates @AlyssaDotCom @TouchByAM #NoRA',
#     'favourites_count': 18131,
#     'follow_request_sent': None,
#     'followers_count': 3567522,
#     'following': None,
#     'friends_count': 3959,
#     'geo_enabled': True,
#     'id': 26642006,
#     'id_str': '26642006',
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 37542,
#     'location': 'Los Angeles',
#     'name': 'Alyssa Milano',
#     'notifications': None,
#     'profile_background_color': '260808',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26642006/1557181528',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1126230170522644480/jMfg6Vdd_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1126230170522644480/jMfg6Vdd_normal.jpg',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '77BF56',
#     'profile_sidebar_fill_color': 'A5C44F',
#     'profile_text_color': 'EBE18F',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Alyssa_Milano',
#     'statuses_count': 56511,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://alyssa.com',
#     'utc_offset': None,
#     'verified': True}},
#   'quoted_status_id': 1127040792281767936,
#   'quoted_status_id_str': '1127040792281767936',
#   'quoted_status_permalink': {'display': 'twitter.com/alyssa_milano/…',
#    'expanded': 'https://twitter.com/alyssa_milano/status/1127040792281767936',
#    'url': 'https://t.co/XrKqv1iQMn'},
#   'reply_count': 1996,
#   'retweet_count': 4016,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'This is the greatest tweet that has ever been put forth to humanity. \n\nMy eyes will never again gaze upon anything… https://t.co/8rz0IZkKWa',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Tue Jun 30 07:52:26 +0000 2009',
#    'default_profile': True,
#    'default_profile_image': False,
#    'description': '#WalkAway Campaign Founder. BOOKING/PRESS INQUIRIES: bstrakabooking@gmail.com Former Liberal. Gay. Conservative. Outspoken. On a mission to #RedPill humanity 💊',
#    'favourites_count': 16578,
#    'follow_request_sent': None,
#    'followers_count': 168805,
#    'following': None,
#    'friends_count': 409,
#    'geo_enabled': True,
#    'id': 52338305,
#    'id_str': '52338305',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 516,
#    'location': 'New York, USA',
#    'name': 'Brandon Straka',
#    'notifications': None,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/52338305/1547102017',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/998414118561316864/wT9_5MUw_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/998414118561316864/wT9_5MUw_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'usminority',
#    'statuses_count': 5557,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://WalkAwayCampaign.com',
#    'utc_offset': None,
#    'verified': False}},
#  'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#  'text': 'RT @usminority: This is the greatest tweet that has ever been put forth to humanity. \n\nMy eyes will never again gaze upon anything on twitt…',
#  'timestamp_ms': '1557666434833',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Wed Feb 23 01:55:18 +0000 2011',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'I am a writer, photographer, historian and soon to be blogger.',
#   'favourites_count': 36238,
#   'follow_request_sent': None,
#   'followers_count': 843,
#   'following': None,
#   'friends_count': 2485,
#   'geo_enabled': True,
#   'id': 256297284,
#   'id_str': '256297284',
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 2,
#   'location': 'Houston, TX',
#   'name': 'Alecia Alexander',
#   'notifications': None,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_normal.png',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'aleciaalexander',
#   'statuses_count': 26572,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': None,
#   'verified': False}}
