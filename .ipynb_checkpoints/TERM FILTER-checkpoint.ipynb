# %% [markdown]
# # STREAM PROCESSING
#
# 1. LOCATION filter is tricky
# 2. Streaming connects to the “public streams” (all public data)
#
# Example of parameter setting done in stream filter
#
# ```
# stream.filter(follow=["2211149702"])
# ```

# %%
import datetime


f = open("../donotgit/access.txt", "r")
keys = f.read()
f.close()
keys  = keys.split(',')
#print("Access Keys are : " + str(keys))
ACCESS_TOKEN = keys[0]
ACCESS_SECRET = keys[1]


f = open("../donotgit/consumer.txt", "r")
keys = f.read()
keys  = keys.split(',')
#print("Consumer Keys are : " + str(keys))
CONSUMER_KEY = keys[0]
CONSUMER_SECRET = keys[1]

# %%
# Import the necessary package to process data in JSON format
try:
    import json
except ImportError:
    import simplejson as json

# Import the tweepy library
import tweepy

# Variables that contains the user credentials to access Twitter API 
# Captured earlier 

# Setup tweepy to authenticate with Twitter credentials:

auth = tweepy.OAuthHandler(CONSUMER_KEY, CONSUMER_SECRET)
auth.set_access_token(ACCESS_TOKEN, ACCESS_SECRET)

# Create the api to connect to twitter with your creadentials
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, compression=True)

status_array = []

class StreamListener(tweepy.StreamListener):

    def on_status(self, status):
        status_array.append(status._json)
        print(status.text)
        
    def on_error(self, status_code):
        if status_code == 420:
            return False

stream_listener = StreamListener()
stream = tweepy.Stream(auth=api.auth, listener=stream_listener)

stream.filter(track=["SexStrike"],languages=["en"])
# Out:
# RT @RealCandaceO: From an evolutionary perspective, the radical feminist #sexstrike has the potential to save America.
#
# Yes, ladies—leave…
# RT @usminority: This is the greatest tweet that has ever been put forth to humanity.
#
# My eyes will never again gaze upon anything on twitt…
# RT @ericisaac: .@Alyssa_Milano calls for all women to withhold sex from men while she has no issue fucking the entire country by helping @J…
# RT @LATiffani1: Go on a  #SexStrike Alyssa Milano.
#
# America can be unburdened from you and your liberal progressive hairy arm pitted pals…
# RT @KristySwansonXO: Wow! Today’s my lucky day 😂🤣 https://t.co/oq1oOpGONW
# RT @shannonrwatts: Rape has nothing to do with sex - it’s about hatred and power, the same causes of women being stripped of their rights.…
# RT @usminority: Why do I get the feeling tens of millions of men are about to #Sexit the Democratic Party? https://t.co/XrKqv1iQMn
# RT @PenceConscience: It is time for me too enter the battle. How many women over the years have fawned over this? Look at my poseture, #Kan…
# RT @stillnaima: Lmao.
# No.
#
# This actually SUPPORTS the idea that we’re just walking vaginas, and/or only here to serve men’s sexual needs. A…
# RT @heyyguido: My problem with this #SexStrike
# It feeds the narrative that women only have sex to satisfy men’s sexual needs. It ignores wo…
# RT @RealCandaceO: From an evolutionary perspective, the radical feminist #sexstrike has the potential to save America.
#
# Yes, ladies—leave…
# Excited to ask wifey about the #SexStrike
#
# Trying to guess her response.
#
# A - awesome
# B - that's stupid
# C - she d… https://t.co/moubS6KbWn
# RT @MichaelLeeFree3: BREAKING:
#
# Stormy Daniel's in a show of unity and support for #SexStrike has offered to do a series speeches on 'abst…
# RT @JackPosobiec: And just like thay the Left is practicing abstinence - this is what we Catholics have been teaching all along!
#
# Carry on…
# @Alyssa_Milano Humm !! #SexStrike ?
# Fact : 7 Out Of 10 Women Cheat On Spouses In India, Claims Survey .… https://t.co/GkDD7GRkEK
# RT @RedTRaccoon: I support her #SexStrike and all the other women who choose to participate.
#
# I support a woman's choice in everything.
#
# My…
# RT @KatTheHammer1: Bette Midler joins sex strike protest....😏
#
# #sexstrike 😂😂 https://t.co/myX6Yuszto
# RT @Alyssa_Milano: Our reproductive rights are being erased.
#
# Until women have legal control over our own bodies we just cannot risk pregna…
# RT @nwbtcw: Yeah, a #SexStrike is cool, but have you ever collectively skipped work across the country until the ruling class is forced to…
# RT @almostjingo: Is this your way of saying your affair with the Netflix dude is over? Oops did I say that out loud. https://t.co/a8gO9dI0sG
# RT @TalbertSwan: The problem with the #SexStrike is that the old conservative racist white men who are more concerned with building walls a…
# RT @shannonrwatts: Rape has nothing to do with sex - it’s about hatred and power, the same causes of women being stripped of their rights.…
# RT @thecjpearson: I’m sorry but I’m not sure how consequential women who don’t shave their underarms and wear vaginas on their head partici…
# Hey Alyssa Milano, defend women’s bodily autonomy or defend Joe Biden. You cannot do both. #SexStrike
# RT @LoriinUtah: Since when do women not have legal control over their bodies @Alyssa_Milano? I will tell you when: When they are being brut…
# RT @benshapiro: In which the Left discovers traditional sexual morality https://t.co/teNHY3T34d
# RT @PennyRed: Here’s the #SexStrike that matters:
# Do not sleep with anyone who believes in forcing women to give birth.
# Do not fuck misogy…
# RT @mostlybree: I'm going to pretend SexStrike isn't happening for 8,000 reasons large and small but particularly because reinforcing the u…
# RT
# RT @usminority: Why do I get the feeling tens of millions of men are about to #Sexit the Democratic Party? https://t.co/XrKqv1iQMn
# Well that’s one way to stop people from aborting babies. Hmmm, don’t make babies.
# RT @RealCandaceO: From an evolutionary perspective, the radical feminist #sexstrike has the potential to save America.
#
# Yes, ladies—leave…
# I finally understand the #SexStrike!
# RT @RepStevenSmith: They've officially lost it, folks.
#
# But at least they're not reproducing anymore. #SexStrike https://t.co/f11kl0l7YI
# RT @andizeisler: I know this is well-meaning but the WHOLE. ENTIRE. POINT. of these horrifying laws is to punish women for daring to have a…

# %%
currentDT = datetime.datetime.now()
filename = "data/streamout-" + str(currentDT) + ".txt"
reportfile = "reports/printout-"+ str(currentDT) + ".txt"
print(filename)

with open(filename, 'w') as f:
    for item in status_array:
        f.write("%s\n" % item)
f.close()
# Out:
# data/streamout-2019-05-12 13:51:27.012035.txt

# %%
len(status_array)
# Out:
# 79

# %%
 
with open(reportfile, 'w') as f:
    for y in range(0, len(status_array)):
        f.write('************************************************************\n')
        f.write(status_array[y]['text'])
        f.write('------------------------------\n')
        f.write(status_array[y]['created_at'])
        f.write('------------------------------\n')
        f.write(status_array[y]['user']['name'])
        f.write('------------------------------\n')
        f.write(str(status_array[y]['user']['location']))
        f.write('------------------------------\n')
        f.write(str(status_array[y]['user']['description']))
        f.write('--------------REPLY COUNT----------------\n|')
        f.write(str(status_array[y]['reply_count']))
        f.write('--------------RETWEET COUNT----------------\n')
        f.write(str(status_array[y]['retweet_count']))
        f.write('--------------RETWEETED?----------------\n')
        f.write(str(status_array[y]['retweeted']))
        f.write('--------------RETWEET COUNT----------------\n')
        f.write(str(status_array[y]['retweet_count']))
        f.write('--------------FAVOURITED----------------\n')
        f.write(str(status_array[y]['favorited']))
        f.write('--------------FAVOURITE COUNT----------------\n')
        f.write(str(status_array[y]['favorite_count']))
        f.write('\n')
        f.write('\n')
        
f.close()
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
    
for x in range(0, len(status_array)):
    print('************************************************************')
    print(status_array[x]['text'])
    print('------------------------------')
    print(status_array[x]['created_at'])
    print('------------------------------')
    print(status_array[x]['user']['name'])
    print('------------------------------')
    print(status_array[x]['user']['location'])
    print('------------------------------')
    print(status_array[x]['user']['description'])
    print('--------------REPLY COUNT----------------')
    print(status_array[x]['reply_count'])
    print('--------------RETWEET COUNT----------------')
    print(status_array[x]['retweet_count'])
    print('--------------RETWEETED?----------------')
    print(status_array[x]['retweeted'])
    print('--------------RETWEET COUNT----------------')
    print(status_array[x]['retweet_count'])
    print('--------------FAVOURITED----------------')
    print(status_array[x]['favorited'])
    print('--------------FAVOURITE COUNT----------------')
    print(status_array[x]['favorite_count'])
    print('')
    print('')
# Out:
# ************************************************************
# RT @KatTimpf: Lol. I thought you were “woke” enough to know that women like sex for sex’s sake too. But great job promoting the antiquated…
# ------------------------------
# Sun May 12 11:21:32 +0000 2019
# ------------------------------
# Eikoh3 🐕🐾🐾
# ------------------------------
# Huntersville, NC
# ------------------------------
# Animal Lover, Staunch Conservative, Former RN, Former Flight Attendant for Major Airline Carrier, Proud member of the Baby Boomer Generation
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @ScottPresler: Liberal women having a #SexStrike means
#
# conservative women will be having more babies.
#
# I fully support this pro-life…
# ------------------------------
# Sun May 12 11:21:35 +0000 2019
# ------------------------------
# Carol Hagerman
# ------------------------------
# Northern Indiana/Chicago USA
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @GrahamAllen_1: Ladies,
#
# If you need a “typical” Hollywood elitist like @Alyssa_Milano to tell you to stop having sex so you don’t have…
# ------------------------------
# Sun May 12 11:21:41 +0000 2019
# ------------------------------
# Kevin Alexander
# ------------------------------
# Locust, NC
# ------------------------------
# Husband to a wonderful wife and Father of two kids.  When I am not at work I spent time with family and play a little golf.
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @Alyssa_Milano: Our reproductive rights are being erased.
#
# Until women have legal control over our own bodies we just cannot risk pregna…
# ------------------------------
# Sun May 12 11:21:43 +0000 2019
# ------------------------------
# Steven Vasen
# ------------------------------
# Zaanstad
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @delmoi: So I went back and checked -  turns out 70% of WHITE WOMEN voted for this Georgia governor who just signed the abortion ban tha…
# ------------------------------
# Sun May 12 11:21:44 +0000 2019
# ------------------------------
# grid acolyte
# ------------------------------
# milliways
# ------------------------------
# believe 6 impossible things before breakfast every day #equality #energy #environment #abolitionist
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @tweetwithfury: I've been married a long time and our kids are teenagers.  My wife STILL glows when talking about our kids.
#
# Mother ho…
# ------------------------------
# Sun May 12 11:21:45 +0000 2019
# ------------------------------
# 𝐃𝐀𝐕𝐈𝐃 𝐀. 𝐕𝐎𝐒𝐒 ⭐⭐⭐💣💥💥💥🇺🇸
# ------------------------------
# North Dakota, USA
# ------------------------------
# 𝐈 𝐝𝐨 𝐧𝐨𝐭 𝐠𝐞𝐭 𝐩𝐚𝐢𝐝 𝐭𝐨 𝐰𝐨𝐫𝐫𝐲 𝐚𝐛𝐨𝐮𝐭 𝐡𝐨𝐰 𝐲𝐨𝐮 𝐰𝐨𝐫𝐫𝐲 𝐚𝐛𝐨𝐮𝐭 𝐡𝐨𝐰 𝐈 𝐬𝐡𝐨𝐮𝐥𝐝 𝐭𝐡𝐢𝐧𝐤👌#WWG1WGA🤘
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @KevinMFerrara: @NahBabyNah It’s easy to have a #SexStrike when you’re not getting any, are you Alyssa Milano? https://t.co/AudHB7sJPK
# ------------------------------
# Sun May 12 11:21:45 +0000 2019
# ------------------------------
# Ann Thacker ❤️🇺🇸🇺🇸
# ------------------------------
# Tennessee, USA
# ------------------------------
# Proud to be an American 🇺🇸🧱kateswall🇺🇸MAGA Patriot🇺🇸KAG20🇺🇸 Married! 🚫NO LISTS NO PORN‼️ 🌺 If I haven’t followed you back let me know 🚂. CodeOfVets
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @inthelineofmel: Or you could just get married, realize that pregnancy is not a disease or sickness, and stop using sex as a weapon and…
# ------------------------------
# Sun May 12 11:21:46 +0000 2019
# ------------------------------
# yung seaman 🇺🇸🇲🇽
# ------------------------------
# 210
# ------------------------------
# US Navy ⚓️ 210➡️Virginia Beach
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @Fidaddle: I’m going on a #SexStrike
#
# From this moment forward, I won’t have sex with rude men, men who can’t get me to laugh, men who w…
# ------------------------------
# Sun May 12 11:21:47 +0000 2019
# ------------------------------
# Homa Says
# ------------------------------
# None
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# Epic
# ------------------------------
# Sun May 12 11:21:48 +0000 2019
# ------------------------------
# RGB
# ------------------------------
# None
# ------------------------------
# The problem is not that people are taxed too little, the problem is that government spends too much         ~Ronald Reagan
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @PenceConscience: Pence was the first man to comment on the #SexStrike. He said to BRING IT ON! No MAN ever needs to sleep with a WOMAN…
# ------------------------------
# Sun May 12 11:21:52 +0000 2019
# ------------------------------
# Donald J. Trump (Parody)
# ------------------------------
# White House
# ------------------------------
# ***Trump Parodee Account***  DID A TWEET FOOL YOU? It's a compliment! #FBR #Resist Formally  #PenceConscience #AltVPPence
# THURSDAY is SHOUT OUT DAY!
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT

# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @Susan_ishere: Don't be too disappointed fellas.  😂😱 https://t.co/5LC6Gx2zkq
# ------------------------------
# Sun May 12 11:22:26 +0000 2019
# ------------------------------
# GPRacer51
# ------------------------------
# None
# ------------------------------
# ⭐️⭐️⭐️Sick and tired of all the BS floating about our wonderful Planet Earth. Trying to help clear it out.⭐️⭐️⭐️🇦🇺🇦🇺🇦🇺
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# #SexStrike is a great idea as it will definitely put a damper on abortions!
# #ProChoice
# ------------------------------
# Sun May 12 11:22:26 +0000 2019
# ------------------------------
# (((Crusader))) #ImpeachTrump 🍑
# ------------------------------
# Menifee, CA
# ------------------------------
# Crusader is my full legal name. Formerly known as Andrew Exler.  Overturned Disneyland's ban on same-sex dancing in 1980s. Proofread court transcripts for $.
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @AngryBlackLady: No. This is heteronormative slacktivist garbage borne of patriarchy and it literally does nothing to help pregnant peop…
# ------------------------------
# Sun May 12 11:22:27 +0000 2019
# ------------------------------
# Shambu Shunya
# ------------------------------
# None
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @joegooding: This! 👇 @michellemalkin officially out of shits to give. 😂 https://t.co/xSWeDcGdML
# ------------------------------
# Sun May 12 11:22:28 +0000 2019
# ------------------------------
# Tom Nash
# ------------------------------
# Amarillo, TX
# ------------------------------
# Classic Rock,Southern Rock and Good Country
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @DaisyCousens: Well, if the pro-choice crowd aren't having sex, at least the number of abortions will likely go down 🤷🏼‍♀️ Hang on...isn…
# ------------------------------
# Sun May 12 11:22:30 +0000 2019
# ------------------------------
# StarWars4Life
# ------------------------------
# None
# ------------------------------
# Hi I’m StarWars4Life.I enjoy everything StarWars & WonderWomen. Im also a big fan of Geeks&Gamers and I have an Instagram dedicated to Jeremy jgg4life 💚
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @JoeTalkShow: just so I understand, @Alyssa_Milano (who was great in Commando) is calling for women who are FOR killing unborn babies to…
# ------------------------------
# Sun May 12 11:22:31 +0000 2019
# ------------------------------
# Grace Rohlf
# ------------------------------
# None
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @AGerberBaby: Great idea! Maybe then you cease murdering babies for awhile.
# #AbortionIsNotHealthcare #AbortionIsMurder https://t.co/e7pQ…
# ------------------------------
# Sun May 12 11:22:32 +0000 2019
# ------------------------------
# The Sly {⭐️} Silver Fox🥓⭐️⭐️⭐️
# ------------------------------
# United States
# ------------------------------
# Followed by @GenFlynn, @RealDrGina,@CarlaDaddesi,@JessieJaneDuff,@RitaCosby, @deneenborelli, @katiet121, @michellemakori -Touch Not A Catt Bot A Targe
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @ErisofEliza: I feel like the #SexStrike is a subtle confession by straight white liberal women that they are having sex with the absolu…
# ------------------------------
# Sun May 12 11:22:33 +0000 2019
# ------------------------------
# Adiza
# ------------------------------
# None
# ------------------------------
# Singer of songs, drinker of wines.
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @RealOmarNavarro: I refuse to have a #sexstrike tonight.
# ------------------------------
# Sun May 12 11:22:33 +0000 2019
# ------------------------------
# Lala Downey
# ------------------------------
# None
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @Imamofpeace: Can you please make sure that Ilhan Omar and Rashida Tlaib also participate in this strike? Thank you. https://t.co/7sanvo…
# ------------------------------
# Sun May 12 11:22:33 +0000 2019
# ------------------------------
# Sheela Gaikwad
# ------------------------------
# None
# ------------------------------
# YOLO
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @usminority: This is the greatest tweet that has ever been put forth to humanity.
#
# My eyes will never again gaze upon anything on twitt…
# ------------------------------
# Sun May 12 11:22:37 +0000 2019
# ------------------------------
# Steeler Keith
# ------------------------------
# Pennsylvania
# ------------------------------
# Hardworking family and tired of the gov corruption. Strong supporter of Donald Trump and his family
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @GrahamAllen_1: Ladies,
#
# If you need a “typical” Hollywood elitist like @Alyssa_Milano to tell you to stop having sex so you don’t have…
# ------------------------------
# Sun May 12 11:22:38 +0000 2019
# ------------------------------
# Jenn
# ------------------------------
# New York, USA
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @EdIsBackKAG2020: The only love this spoiled #HollywoodHasBeen is getting these days is from #Lucifer himself 👿 #SexBoycott #SexStrike @…
# ------------------------------
# Sun May 12 11:22:38 +0000 2019
# ------------------------------
# The Honorable Harry
# ------------------------------
# Twitter Keeps Me Busy🇺🇸
# ------------------------------
# #MAGA👍
# #AMERICAFIRST🇺🇸🇺🇸 🇺🇸🇺🇸🇺🇸
# VOTE IN🇺🇸 #election2020🇺🇸
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @SayWhenLA: Listen, Kate. Listen good. You're falling for the divisive narrative planted by the powers at be to separate us all, so they…
# ------------------------------
# Sun May 12 11:22:39 +0000 2019
# ------------------------------
# Dagdag⭐⭐⭐
# ------------------------------
# Gulf Coast, MS
# ------------------------------
# 🇺🇸 America First 🇺🇸 BeBest  🇺🇸 TRUMP 🇺🇸 Blind Justice Under the Law Will Return to Our Republic
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @usminority: Why do I get the feeling tens of millions of men are about to #Sexit the Democratic Party? https://t.co/XrKqv1iQMn
# ------------------------------
# Sun May 12 11:22:39 +0000 2019
# ------------------------------
# Kat MagaVet
# ------------------------------
# None
# ------------------------------
# USN vet. Twitter won't let me access my original account of over 8,000 followers which was Kathy Nelson @putzie63
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @thelindsayellis: I can't even with how wrongheaded this #SexStrike is. like where do you even start
# ------------------------------
# Sun May 12 11:22:39 +0000 2019
# ------------------------------
# 2's a party but 3 is a crowd
# ------------------------------
# Pennsylvania, USA
# ------------------------------
# GAMERS RISE UP
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @604yousuf: Due to the prevalence of absent fathers, the rise of the #MeToo movement, and the increased restrictions on access to aborti…
# ------------------------------
# Sun May 12 11:22:39 +0000 2019
# ------------------------------
# Adnan
# ------------------------------
# None
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @Kate_Kelly_Esq: Join us in helping cis men feel the physical consequences of our reproductive rights being systematically eliminated!…
# ------------------------------
# Sun May 12 11:22:40 +0000 2019
# ------------------------------
# Ame 👑
# ------------------------------
# London Institute
# ------------------------------
# There is more to living than not dying.
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# @evaandheriud The funniest thing about this #SexStrike is the thought that liberal women actually believe conservat… https://t.co/NwNpgHWtIS
# ------------------------------
# Sun May 12 11:22:40 +0000 2019
# ------------------------------
# Jeannie-ology
# ------------------------------
# USA
# ------------------------------
# Writer @AmericanThinker, Live Action, ClashDaily. Christian wife,Mom & Grandma exposing liberalism via truth, humor, & Sicilian-style sarcasm #Outlander fan.
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# RT @jillboard: i’ve been on a #SexStrike from men for years where’s my fuckin medal
# ------------------------------
# Sun May 12 11:22:41 +0000 2019
# ------------------------------
# 🌻 pepper potts 🌻
# ------------------------------
# Garden City, MI
# ------------------------------
# Severus Snape is gross. ✌️ ✨Always let your conscience be your guide.✨
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0
#
#
# ************************************************************
# #SexStrike: Alyssa Milano Asks Women To Cut Off Sex With Men In Protest Of Georgia’s Abortion Law https://t.co/DUE2fMG2ZF
# ------------------------------
# Sun May 12 11:22:42 +0000 2019
# ------------------------------
# Sokende Sanndru
# ------------------------------
# None
# ------------------------------
# None
# --------------REPLY COUNT----------------
# 0
# --------------RETWEET COUNT----------------
# 0
# --------------RETWEETED?----------------
# False
# --------------RETWEET COUNT----------------
# 0
# --------------FAVOURITED----------------
# False
# --------------FAVOURITE COUNT----------------
# 0

# %%
status_array[0]
# Out:
# {'contributors': None,
#  'coordinates': None,
#  'created_at': 'Sun May 12 11:21:32 +0000 2019',
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'urls': [],
#   'user_mentions': [{'id': 170861207,
#     'id_str': '170861207',
#     'indices': [3, 12],
#     'name': 'Kat Timpf',
#     'screen_name': 'KatTimpf'}]},
#  'favorite_count': 0,
#  'favorited': False,
#  'filter_level': 'low',
#  'geo': None,
#  'id': 1127534268966735872,
#  'id_str': '1127534268966735872',
#  'in_reply_to_screen_name': None,
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'is_quote_status': True,
#  'lang': 'en',
#  'place': None,
#  'quote_count': 0,
#  'quoted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat May 11 02:40:38 +0000 2019',
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1127040792281767936',
#      'indices': [117, 140],
#      'url': 'https://t.co/TsIN3KUQM7'}],
#    'user_mentions': []},
#   'extended_tweet': {'display_text_range': [0, 230],
#    'entities': {'hashtags': [{'indices': [207, 217], 'text': 'SexStrike'}],
#     'media': [{'display_url': 'pic.twitter.com/uOgN4FKwpg',
#       'expanded_url': 'https://twitter.com/Alyssa_Milano/status/1127040792281767936/photo/1',
#       'id': 1127040785952546817,
#       'id_str': '1127040785952546817',
#       'indices': [231, 254],
#       'media_url': 'http://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#       'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1582},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 927},
#        'small': {'h': 680, 'resize': 'fit', 'w': 525},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/uOgN4FKwpg'}],
#     'symbols': [],
#     'urls': [],
#     'user_mentions': []},
#    'extended_entities': {'media': [{'display_url': 'pic.twitter.com/uOgN4FKwpg',
#       'expanded_url': 'https://twitter.com/Alyssa_Milano/status/1127040792281767936/photo/1',
#       'id': 1127040785952546817,
#       'id_str': '1127040785952546817',
#       'indices': [231, 254],
#       'media_url': 'http://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#       'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1582},
#        'medium': {'h': 1200, 'resize': 'fit', 'w': 927},
#        'small': {'h': 680, 'resize': 'fit', 'w': 525},
#        'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#       'type': 'photo',
#       'url': 'https://t.co/uOgN4FKwpg'}]},
#    'full_text': 'Our reproductive rights are being erased.\n\nUntil women have legal control over our own bodies we just cannot risk pregnancy. \n\nJOIN ME by not having sex until we get bodily autonomy back.\n\nI’m calling for a #SexStrike. Pass it on. https://t.co/uOgN4FKwpg'},
#   'favorite_count': 38459,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 1127040792281767936,
#   'id_str': '1127040792281767936',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'quote_count': 20304,
#   'reply_count': 38519,
#   'retweet_count': 13076,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Our reproductive rights are being erased.\n\nUntil women have legal control over our own bodies we just cannot risk p… https://t.co/TsIN3KUQM7',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Thu Mar 26 00:34:20 +0000 2009',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': '🇺🇸 Check out @sorrynotsorry @PatNotPart and @NoRA4USA Please follow my other accounts for career updates @AlyssaDotCom @TouchByAM #NoRA',
#    'favourites_count': 18131,
#    'follow_request_sent': None,
#    'followers_count': 3567351,
#    'following': None,
#    'friends_count': 3959,
#    'geo_enabled': True,
#    'id': 26642006,
#    'id_str': '26642006',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 37540,
#    'location': 'Los Angeles',
#    'name': 'Alyssa Milano',
#    'notifications': None,
#    'profile_background_color': '260808',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26642006/1557181528',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1126230170522644480/jMfg6Vdd_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1126230170522644480/jMfg6Vdd_normal.jpg',
#    'profile_link_color': 'E81C4F',
#    'profile_sidebar_border_color': '77BF56',
#    'profile_sidebar_fill_color': 'A5C44F',
#    'profile_text_color': 'EBE18F',
#    'profile_use_background_image': True,
#    'protected': False,
#    'screen_name': 'Alyssa_Milano',
#    'statuses_count': 56511,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://alyssa.com',
#    'utc_offset': None,
#    'verified': True}},
#  'quoted_status_id': 1127040792281767936,
#  'quoted_status_id_str': '1127040792281767936',
#  'quoted_status_permalink': {'display': 'twitter.com/alyssa_milano/…',
#   'expanded': 'https://twitter.com/alyssa_milano/status/1127040792281767936',
#   'url': 'https://t.co/fJeYdq9qF3'},
#  'reply_count': 0,
#  'retweet_count': 0,
#  'retweeted': False,
#  'retweeted_status': {'contributors': None,
#   'coordinates': None,
#   'created_at': 'Sat May 11 19:54:57 +0000 2019',
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#      'expanded_url': 'https://twitter.com/i/web/status/1127301085062934528',
#      'indices': [117, 140],
#      'url': 'https://t.co/TmPabQl8G2'}],
#    'user_mentions': []},
#   'extended_tweet': {'display_text_range': [0, 254],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/alyssa_milano/…',
#       'expanded_url': 'https://twitter.com/alyssa_milano/status/1127040792281767936',
#       'indices': [255, 278],
#       'url': 'https://t.co/fJeYdq9qF3'}],
#     'user_mentions': []},
#    'full_text': 'Lol. I thought you were “woke” enough to know that women like sex for sex’s sake too. But great job promoting the antiquated narrative that women do it only as a concession/gift to men, and somehow thinking you’re doing so in the name of “progressivism.” https://t.co/fJeYdq9qF3'},
#   'favorite_count': 3608,
#   'favorited': False,
#   'filter_level': 'low',
#   'geo': None,
#   'id': 1127301085062934528,
#   'id_str': '1127301085062934528',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': True,
#   'lang': 'en',
#   'place': None,
#   'possibly_sensitive': False,
#   'quote_count': 66,
#   'quoted_status': {'contributors': None,
#    'coordinates': None,
#    'created_at': 'Sat May 11 02:40:38 +0000 2019',
#    'display_text_range': [0, 140],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'urls': [{'display_url': 'twitter.com/i/web/status/1…',
#       'expanded_url': 'https://twitter.com/i/web/status/1127040792281767936',
#       'indices': [117, 140],
#       'url': 'https://t.co/TsIN3KUQM7'}],
#     'user_mentions': []},
#    'extended_tweet': {'display_text_range': [0, 230],
#     'entities': {'hashtags': [{'indices': [207, 217], 'text': 'SexStrike'}],
#      'media': [{'display_url': 'pic.twitter.com/uOgN4FKwpg',
#        'expanded_url': 'https://twitter.com/Alyssa_Milano/status/1127040792281767936/photo/1',
#        'id': 1127040785952546817,
#        'id_str': '1127040785952546817',
#        'indices': [231, 254],
#        'media_url': 'http://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#        'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1582},
#         'medium': {'h': 1200, 'resize': 'fit', 'w': 927},
#         'small': {'h': 680, 'resize': 'fit', 'w': 525},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/uOgN4FKwpg'}],
#      'symbols': [],
#      'urls': [],
#      'user_mentions': []},
#     'extended_entities': {'media': [{'display_url': 'pic.twitter.com/uOgN4FKwpg',
#        'expanded_url': 'https://twitter.com/Alyssa_Milano/status/1127040792281767936/photo/1',
#        'id': 1127040785952546817,
#        'id_str': '1127040785952546817',
#        'indices': [231, 254],
#        'media_url': 'http://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#        'media_url_https': 'https://pbs.twimg.com/media/D6QNn54UIAEauiX.jpg',
#        'sizes': {'large': {'h': 2048, 'resize': 'fit', 'w': 1582},
#         'medium': {'h': 1200, 'resize': 'fit', 'w': 927},
#         'small': {'h': 680, 'resize': 'fit', 'w': 525},
#         'thumb': {'h': 150, 'resize': 'crop', 'w': 150}},
#        'type': 'photo',
#        'url': 'https://t.co/uOgN4FKwpg'}]},
#     'full_text': 'Our reproductive rights are being erased.\n\nUntil women have legal control over our own bodies we just cannot risk pregnancy. \n\nJOIN ME by not having sex until we get bodily autonomy back.\n\nI’m calling for a #SexStrike. Pass it on. https://t.co/uOgN4FKwpg'},
#    'favorite_count': 38459,
#    'favorited': False,
#    'filter_level': 'low',
#    'geo': None,
#    'id': 1127040792281767936,
#    'id_str': '1127040792281767936',
#    'in_reply_to_screen_name': None,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'is_quote_status': False,
#    'lang': 'en',
#    'place': None,
#    'possibly_sensitive': False,
#    'quote_count': 20304,
#    'reply_count': 38519,
#    'retweet_count': 13076,
#    'retweeted': False,
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'text': 'Our reproductive rights are being erased.\n\nUntil women have legal control over our own bodies we just cannot risk p… https://t.co/TsIN3KUQM7',
#    'truncated': True,
#    'user': {'contributors_enabled': False,
#     'created_at': 'Thu Mar 26 00:34:20 +0000 2009',
#     'default_profile': False,
#     'default_profile_image': False,
#     'description': '🇺🇸 Check out @sorrynotsorry @PatNotPart and @NoRA4USA Please follow my other accounts for career updates @AlyssaDotCom @TouchByAM #NoRA',
#     'favourites_count': 18131,
#     'follow_request_sent': None,
#     'followers_count': 3567351,
#     'following': None,
#     'friends_count': 3959,
#     'geo_enabled': True,
#     'id': 26642006,
#     'id_str': '26642006',
#     'is_translator': False,
#     'lang': 'en',
#     'listed_count': 37540,
#     'location': 'Los Angeles',
#     'name': 'Alyssa Milano',
#     'notifications': None,
#     'profile_background_color': '260808',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/26642006/1557181528',
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1126230170522644480/jMfg6Vdd_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1126230170522644480/jMfg6Vdd_normal.jpg',
#     'profile_link_color': 'E81C4F',
#     'profile_sidebar_border_color': '77BF56',
#     'profile_sidebar_fill_color': 'A5C44F',
#     'profile_text_color': 'EBE18F',
#     'profile_use_background_image': True,
#     'protected': False,
#     'screen_name': 'Alyssa_Milano',
#     'statuses_count': 56511,
#     'time_zone': None,
#     'translator_type': 'none',
#     'url': 'http://alyssa.com',
#     'utc_offset': None,
#     'verified': True}},
#   'quoted_status_id': 1127040792281767936,
#   'quoted_status_id_str': '1127040792281767936',
#   'quoted_status_permalink': {'display': 'twitter.com/alyssa_milano/…',
#    'expanded': 'https://twitter.com/alyssa_milano/status/1127040792281767936',
#    'url': 'https://t.co/fJeYdq9qF3'},
#   'reply_count': 340,
#   'retweet_count': 604,
#   'retweeted': False,
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'text': 'Lol. I thought you were “woke” enough to know that women like sex for sex’s sake too. But great job promoting the a… https://t.co/TmPabQl8G2',
#   'truncated': True,
#   'user': {'contributors_enabled': False,
#    'created_at': 'Sun Jul 25 23:45:18 +0000 2010',
#    'default_profile': False,
#    'default_profile_image': False,
#    'description': 'doing my best',
#    'favourites_count': 15546,
#    'follow_request_sent': None,
#    'followers_count': 321470,
#    'following': None,
#    'friends_count': 520,
#    'geo_enabled': True,
#    'id': 170861207,
#    'id_str': '170861207',
#    'is_translator': False,
#    'lang': 'en',
#    'listed_count': 2018,
#    'location': 'NYC via DC via LA via DET',
#    'name': 'Kat Timpf',
#    'notifications': None,
#    'profile_background_color': '000105',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_tile': True,
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/170861207/1534479324',
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1106161708287098881/_cSuaQif_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1106161708287098881/_cSuaQif_normal.jpg',
#    'profile_link_color': '491F99',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'BFBFD5',
#    'profile_text_color': 'A7CBDA',
#    'profile_use_background_image': False,
#    'protected': False,
#    'screen_name': 'KatTimpf',
#    'statuses_count': 31804,
#    'time_zone': None,
#    'translator_type': 'none',
#    'url': 'http://www.nationalreview.com/author/katherine-timpf',
#    'utc_offset': None,
#    'verified': True}},
#  'source': '<a href="http://twitter.com/#!/download/ipad" rel="nofollow">Twitter for iPad</a>',
#  'text': 'RT @KatTimpf: Lol. I thought you were “woke” enough to know that women like sex for sex’s sake too. But great job promoting the antiquated…',
#  'timestamp_ms': '1557660092952',
#  'truncated': False,
#  'user': {'contributors_enabled': False,
#   'created_at': 'Tue Nov 26 13:22:06 +0000 2013',
#   'default_profile': True,
#   'default_profile_image': False,
#   'description': 'Animal Lover, Staunch Conservative, Former RN, Former Flight Attendant for Major Airline Carrier, Proud member of the Baby Boomer Generation',
#   'favourites_count': 75191,
#   'follow_request_sent': None,
#   'followers_count': 676,
#   'following': None,
#   'friends_count': 207,
#   'geo_enabled': True,
#   'id': 2215716475,
#   'id_str': '2215716475',
#   'is_translator': False,
#   'lang': 'en',
#   'listed_count': 2,
#   'location': 'Huntersville, NC',
#   'name': 'Eikoh3 🐕🐾🐾',
#   'notifications': None,
#   'profile_background_color': 'C0DEED',
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'profile_background_tile': False,
#   'profile_image_url': 'http://pbs.twimg.com/profile_images/822447409821347842/7wB7793a_normal.jpg',
#   'profile_image_url_https': 'https://pbs.twimg.com/profile_images/822447409821347842/7wB7793a_normal.jpg',
#   'profile_link_color': '1DA1F2',
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'profile_text_color': '333333',
#   'profile_use_background_image': True,
#   'protected': False,
#   'screen_name': 'eikoh3',
#   'statuses_count': 56448,
#   'time_zone': None,
#   'translator_type': 'none',
#   'url': None,
#   'utc_offset': None,
#   'verified': False}}

# %%
status_array[0].keys()
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'retweeted_status', 'quoted_status_id', 'quoted_status_id_str', 'quoted_status', 'quoted_status_permalink', 'is_quote_status', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'])
